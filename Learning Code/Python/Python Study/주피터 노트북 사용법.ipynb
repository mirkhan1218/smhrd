# %% [markdown]
# # Jupyter Notebook
#
# 주피터 노트북은 웹 브라우저 상에서 개발을 할 수있는 도구이며, 코드를 cell단위로 묶어서
# 실행하고 그래프나 표 이미지나 영상을 쉽게 볼 수 있어서 특히 데이터 관련 작업을 할 때 많이
# 활용됩니다.
#
# > 재미있는 파이썬 시간!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 특징
#
# 1. 코드를 Cell 단위로 작성 및 실행
# 1. 마크다운을 통한 문서화
# 1. 그래프나 표 등을 실시간으로 확인
# 1. html, pdf 등 파일로 저장할 수있다.

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("환영합니다.")
# Out:
# 환영합니다.

# %%
print("Crtl + Enter : 현재 cell 실행")
# Out:
# Crtl + Enter : 현재 cell 실행

# %%
print("Shift + Enter : 현재 cell 실행 후 다음 cell 선택")
# Out:
# Shift + Enter : 현재 cell 실행 후 다음 cell 선택

# %%
print("Alt + Enter : 현재 cell 실행 후 다음 위치에 cell 삽입")
# Out:
# Alt + Enter : 현재 cell 실행 후 다음 위치에 cell 삽입

# %%
num = 3

# %%
num *= 2

# %%
num += 4

# %%
print(num)
# Out:
# 10

# %% [markdown]
# ## matplotlib
# 그래프 확인 라이브러리

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);  # Plot some data on the axes.

# %% [markdown]
# ## pandas
# 표 확인 라이브러리

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_689a8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_689a8_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_689a8_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_689a8_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_689a8_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_689a8_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_689a8_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_689a8_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_689a8_level1_col4" class="col_heading level1 col4" >Tumour</th>
# ...

# %% [markdown]
# 다음 링크에서 스마트인재개발원의 취업 후기를 확인할 수 있습니다.
# [스마트인재개발원](https://smhrd.or.kr/)

# %%
# %%HTML
# <iframe width="560" height="315" src="https://www.youtube.com/embed/4_-IIfbdR5M" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/4_-IIfbdR5M" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 문자열

# %%
str1 = "Funny Python"
print(str1)
# Out:
# Funny Python

# %%
str2 = "Funny"
str3 = "Python"
print(str2+str3)
print(str2, str3)
# Out:
# FunnyPython
# Funny Python

# %%
srt4 = 'she\'s gone'
print(srt4)
# Out:
# she's gone

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
s = '''자세히 보아야 예쁘다.
오래보아야 사랑스럽다.
너도 그렇다'''
print(s)
# Out:
# 자세히 보아야 예쁘다.
# 오래보아야 사랑스럽다.
# 너도 그렇다

# %%
s = 'My name is BM'

# %%
print(s[8:])
print(s[:7])
print(s)
print(s[-10:-6])
# Out:
# is BM
# My name
# My name is BM
# name

# %%
print(s[11])
print(s[-2])
# Out:
# B
# B

# %% [markdown]
# ###  문자열 포매팅
# - format 함수사용
# - %기호 사용
# - f문자열을 사용

# %%
s = "오늘은 8월 1일 입니다. 1일은 월요일 입니다."
print(s)
# Out:
# 오늘은 8월 1일 입니다. 1일은 월요일 입니다.

# %%
s1 = "오늘은 8월 2일 입니다. 2일은 화요일 입니다."
print(s)
# Out:
# 오늘은 8월 1일 입니다. 1일은 월요일 입니다.

# %%
date = 1
day = "월"

# %%
s = "오늘은 8월 {}일 입니다. {}일은 {}요일 입니다.".format(date, date, day)
print(s)
# Out:
# 오늘은 8월 1일 입니다. 1일은 월요일 입니다.

# %%
s = "오늘은 8월 %d일 입니다. %d일은 %s요일 입니다."%(date, date, day)
print(s)
# Out:
# 오늘은 8월 1일 입니다. 1일은 월요일 입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = f"오늘은 8월 {date}일 입니다. {date}일은 {day}요일 입니다."
print(s)
# Out:
# 오늘은 8월 1일 입니다. 1일은 월요일 입니다.

# %%
x = 100
y = 200
sum2 = x + y
print('{}와 {}의 합은 {}입니다.'.format(x,y,sum2))
print('%d와 %d의 합은 %d입니다.'%(x,y,sum2))
print(f"{x}와 {y}의 합은 {sum2}입니다.")
# Out:
# 100와 200의 합은 300입니다.
# 100와 200의 합은 300입니다.
# 100와 200의 합은 300입니다.

# %%
num1 = 10
str1 = "7"
print(str(num1)+str1)
print(num1+int(str1))
# Out:
# 107
# 17

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = 23
num2 = 3
print(f'더하기 결과 : {num1 + num2}')
print(f'빼기 결과 : {num1 - num2}')
print(f'곱하기 결과 : {num1 * num2}')
print(f'나누기 결과 : {num1 / num2}')
# Out:
# 더하기 결과 : 26
# 빼기 결과 : 20
# 곱하기 결과 : 69
# 나누기 결과 : 7.666666666666667
